# %%
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 14})

# %%
quad = [-5.46086556, -5.2720161,  -5.05618816, -4.84036021, -4.62453227, -4.40870432,
 -4.19287638, -3.97704843, -3.76122048]
sizes = [341.36368777, 261.01063122, 179.86401508, 116.6794973,   90.59406148,
 105.35874026, 156.66479885, 225.73707975, 300.48980261]
sizes_err = [5.12045532, 3.91515947, 2.69796023, 1.75019246, 1.35891092, 1.5803811,
 2.34997198, 3.3860562, 4.50734704]
model = [317.02926957, 254.04216353, 184.81515213, 123.13571428,  86.57834154,
 105.34759643, 160.96815742, 227.76147502, 298.2171842]

# %%
plt.figure(figsize=(3.5,2.5))


plt.errorbar(quad, sizes, yerr=sizes_err, fmt='o', label=f'Measurements')

# Model prediction
plt.errorbar(quad, model, marker='.', label=f'Model')

plt.xlabel('Quadrupole Strength (kG)')
plt.ylabel(r'Beam Size ($\mu$m)')
plt.legend(fontsize=9)


plt.tight_layout()
plt.rcParams.update({
    "savefig.facecolor": (0.0, 0.0, 1.0, 0.0),  # alpha = 0%
})

plt.savefig(f"emit_fit_paper.png", dpi=300)
