# %%
import numpy as np
import matplotlib.pyplot as plt

# importing lcls surrogate model
# %cd ../
from lcls_functions import Lcls

# import pyemittance sample eval function
from pyemittance.emit_eval_example import eval_emit_surrogate
# Out:
# /sdf/home/s/smiskov/emittance_opt_playground

# %% [markdown]
# # Initialize LCLS inj surrogate model

# %%
lcls = Lcls()
fn = lcls.beamsizes_list_fn
def fn_batch(x_list): return [fn(x) for x in x_list]

# define beamsize query function
def get_beamsizes_model(config, val):
    beamsizes_list = fn(config, [val])[0]
    xrms = beamsizes_list[0]
    yrms = beamsizes_list[1]
    xrms_err = xrms*0.03
    yrms_err = yrms*0.03
    
    return xrms, yrms, xrms_err, yrms_err
# Out:
# Add noise:  False

# %% [markdown]
# # Evaluate emittance for some injector configuration

# %% [markdown]
# ### this example function gets the emittance for a given set of injector paramters for: SOL1, CQ1, SQ1

# %%
config_example = [0.46, 0.001, -0.001]
config_example = [0.500237315794103, -0.01867181010308325, -0.00135943489050674, -1, 1, -1, -1, -1]

# %%
#eval_emit_surrogate?

# %%
eval_emit_surrogate(
    get_bs_model=get_beamsizes_model,
    config=config_example,
    quad_init=[-6, -4, -2, 0],
    adapt_ranges=True,
    num_points=7,
    check_sym=False,
    infl_check=False,
    add_pnts=False,
    show_plots=True,
    add_noise=False,
    save_runs=False,
    calc_bmag=False,
)
# Out:
# ====================================================================================================
# * Calling get_beamsize function on [0.500237315794103, -0.01867181010308325, -0.00135943489050674, -1, 1, -1, -1, -1, -6]
#
# ====================================================================================================
# * Calling get_beamsize function on [0.500237315794103, -0.01867181010308325, -0.00135943489050674, -1, 1, -1, -1, -1, -4]
#
# ====================================================================================================
# * Calling get_beamsize function on [0.500237315794103, -0.01867181010308325, -0.00135943489050674, -1, 1, -1, -1, -1, -2]
#
# ====================================================================================================
# * Calling get_beamsize function on [0.500237315794103, -0.01867181010308325, -0.00135943489050674, -1, 1, -1, -1, -1, 0]
#
# ====================================================================================================
# * Calling get_beamsize function on [0.500237315794103, -0.01867181010308325, -0.00135943489050674, -1, 1, -1, -1, -1, 0.0]
#
# ====================================================================================================
# * Calling get_beamsize function on [0.500237315794103, -0.01867181010308325, -0.00135943489050674, -1, 1, -1, -1, -1, 0.2026336384148581]
#
# ====================================================================================================
# * Calling get_beamsize function on [0.500237315794103, -0.01867181010308325, -0.00135943489050674, -1, 1, -1, -1, -1, 0.4052672768297162]
#
# ====================================================================================================
# * Calling get_beamsize function on [0.500237315794103, -0.01867181010308325, -0.00135943489050674, -1, 1, -1, -1, -1, 0.6079009152445745]
#
# ====================================================================================================
# * Calling get_beamsize function on [0.500237315794103, -0.01867181010308325, -0.00135943489050674, -1, 1, -1, -1, -1, 0.8105345536594324]
#
# ====================================================================================================
# * Calling get_beamsize function on [0.500237315794103, -0.01867181010308325, -0.00135943489050674, -1, 1, -1, -1, -1, 1.0131681920742908]
#
# ====================================================================================================
# * Calling get_beamsize function on [0.500237315794103, -0.01867181010308325, -0.00135943489050674, -1, 1, -1, -1, -1, 1.215801830489149]
#
# ====================================================================================================
# * Calling get_beamsize function on [0.500237315794103, -0.01867181010308325, -0.00135943489050674, -1, 1, -1, -1, -1, -6.000000000000001]
#
# ====================================================================================================
# * Calling get_beamsize function on [0.500237315794103, -0.01867181010308325, -0.00135943489050674, -1, 1, -1, -1, -1, -5.156123023600633]
#
# ====================================================================================================
# * Calling get_beamsize function on [0.500237315794103, -0.01867181010308325, -0.00135943489050674, -1, 1, -1, -1, -1, -4.312246047201265]
#
# ====================================================================================================
# * Calling get_beamsize function on [0.500237315794103, -0.01867181010308325, -0.00135943489050674, -1, 1, -1, -1, -1, -3.468369070801897]
#
# ====================================================================================================
# * Calling get_beamsize function on [0.500237315794103, -0.01867181010308325, -0.00135943489050674, -1, 1, -1, -1, -1, -2.624492094402529]
#
# ====================================================================================================
# * Calling get_beamsize function on [0.500237315794103, -0.01867181010308325, -0.00135943489050674, -1, 1, -1, -1, -1, -1.7806151180031615]
#
# ====================================================================================================
# * Calling get_beamsize function on [0.500237315794103, -0.01867181010308325, -0.00135943489050674, -1, 1, -1, -1, -1, -0.9367381416037939]
# ({'nemitx': 0.0005223747770400688,
#   'nemity': 2.2898988297668692e-05,
#   'nemitx_err': 0.00044750012963069586,
#   'nemity_err': 8.372510334890473e-07,
#   'bmagx': None,
#   'bmagy': None,
#   'bmagx_err': None,
#   'bmagy_err': None,
#   'opt_q_x': None,
#   'opt_q_y': None,
#   'quadvalsx': [0.0,
#    0.2026336384148581,
#    0.4052672768297162,
#    0.6079009152445745,
#    0.8105345536594324,
#    1.0131681920742908,
#    1.215801830489149],
#   'beamsizesx': [0.0034663905389606953,
#    0.003444212255999446,
#    0.0034199554938822985,
#    0.0033933562226593494,
#    0.00336394552141428,
#    0.0033317466732114553,
#    0.003296864917501807],
#   'quadvalsy': [-6.000000000000001,
#    -5.156123023600633,
#    -4.312246047201265,
#    -3.468369070801897,
#    -2.624492094402529,
#    -1.7806151180031615,
#    -0.9367381416037939],
#   'beamsizesy': [0.0008664901833981276,
#    0.0007499600760638714,
#    0.0006646426045335829,
#    0.0006211872678250074,
#    0.0006223692325875163,
#    0.0006939793820492923,
#    0.0009197209146805108],
#   'nemit': 0.00010937026061246187,
#   'nemit_err': 9.377896012373865e-05},
#  18)

# %%
config_example = [0.4762182125278053, -0.00027291415901526533, -0.0017033810831913413]

# %%
eval_emit_surrogate(
    get_bs_model=get_beamsizes_model,
    config=config_example,
    quad_init=[-6, -4, -2, 0],
    adapt_ranges=False,
    num_points=7,
    check_sym=False,
    infl_check=False,
    add_pnts=False,
    show_plots=True,
    add_noise=False,
    save_runs=False,
    calc_bmag=False,
)
# Out:
# ({'nemitx': 9.052085827236779e-07,
#   'nemity': 1.1114993848967974e-06,
#   'nemitx_err': 3.183139297329529e-08,
#   'nemity_err': 9.801564159317842e-08,
#   'bmagx': None,
#   'bmagy': None,
#   'bmagx_err': None,
#   'bmagy_err': None,
#   'opt_q_x': None,
#   'opt_q_y': None,
#   'quadvalsx': [-6, -4, -2, 0],
#   'beamsizesx': [0.00030772993341088295,
#    0.0001644843869144097,
#    7.864710642024875e-05,
#    9.804828005144373e-05],
#   'quadvalsy': [-6, -4, -2, 0],
#   'beamsizesy': [0.00017794866289477795,
#    6.531506369356066e-05,
#    0.00024861126439645886,
#    0.0004766665806528181],
#   'nemit': 1.0030646952717804e-06,
#   'nemit_err': 9.522695050973561e-08},
#  4)

# %%
config_example = [0.40237315794103, 0.109867181010308325, 0.009635943489050674]

# %%
eval_emit_surrogate(
    get_bs_model=get_beamsizes_model,
    config=config_example,
    quad_init=[-4,-2, 0, 1],
    adapt_ranges=True,
    num_points=5,
    check_sym=True,
    infl_check=False,
    add_pnts=False,
    show_plots=True,
    add_noise=False,
    save_runs=False,
    calc_bmag=False,
)
# Out:
# ({'nemitx': 9.82084002891222e-05,
#   'nemity': 6.572819964563979e-05,
#   'nemitx_err': 3.901098902439395e-06,
#   'nemity_err': 2.3689020188218115e-06,
#   'bmagx': None,
#   'bmagy': None,
#   'bmagx_err': None,
#   'bmagy_err': None,
#   'opt_q_x': None,
#   'opt_q_y': None,
#   'quadvalsx': [-1.9999999999999998,
#    -1.1960495423777127,
#    -0.3920990847554256,
#    0.4118513728668618,
#    1.215801830489149],
#   'beamsizesx': [0.0011920641409233212,
#    0.0009120642789639533,
#    0.000847330957185477,
#    0.0009442361770197749,
#    0.0012076974380761385],
#   'quadvalsy': [-5.2158018304891485,
#    -4.878356280261218,
#    -4.5409107300332865,
#    -4.203465179805355,
#    -3.866019629577424],
#   'beamsizesy': [0.0005493679200299084,
#    0.0004615760990418494,
#    0.0004386945511214435,
#    0.0005453792400658131,
#    0.0007666285964660347],
#   'nemit': 8.034339637507449e-05,
#   'nemit_err': 4.309308975259467e-06},
#  14)
