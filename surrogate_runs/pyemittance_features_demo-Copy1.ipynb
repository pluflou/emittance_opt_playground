# %%
import numpy as np
import matplotlib.pyplot as plt

# importing lcls surrogate model
# %cd ../
from lcls_functions import Lcls

# import pyemittance sample eval function
from pyemittance.emit_eval_example import eval_emit_surrogate
# Out:
# /Users/smiskov/Documents/SLAC/emittance_opt_playground
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.summary API due to missing TensorBoard installation.

# %% [markdown]
# # Initialize LCLS inj surrogate model

# %%
lcls = Lcls()
fn = lcls.beamsizes_list_fn
def fn_batch(x_list): return [fn(x) for x in x_list]

# define beamsize query function
def get_beamsizes_model(config, val):
    beamsizes_list = fn(config, [val])[0]
    xrms = beamsizes_list[0]
    yrms = beamsizes_list[1]
    xrms_err = xrms*0.03
    yrms_err = yrms*0.03
    
    return xrms, yrms, xrms_err, yrms_err

# %% [markdown]
# # Evaluate emittance for some injector configuration

# %% [markdown]
# ### this example function gets the emittance for a given set of injector paramters for: SOL1, CQ1, SQ1

# %%
config_example = [0.48, -0.01, -0.02]
#config_example = [0.48, -0.010, 0.002]

# %%
eval_emit_surrogate?
# Out:
# Signature:
# eval_emit_surrogate(
#     get_bs_model,
#     config,
#     quad_init=[-6, -4, -2, 0],
#     adapt_ranges=True,
#     num_points=7,
#     check_sym=True,
#     infl_check=True,
#     add_pnts=True,
#     show_plots=False,
#     add_noise=False,
#     save_runs=False,
#     calc_bmag=False,
# )
# Docstring: <no docstring>
# File:      ~/Documents/SLAC/PyEmittance/pyemittance/emit_eval_example.py
# Type:      function

# %%
eval_emit_surrogate(
    get_bs_model=get_beamsizes_model,
    config=config_example,
    quad_init=[-8, -4, -2, 0],
    adapt_ranges=True,
    num_points=7,
    check_sym=True,
    infl_check=True,
    add_pnts=True,
    show_plots=True,
    add_noise=False,
    save_runs=False,
    calc_bmag=True,
)
# Out:
# ({'nemitx': 3.814371975892987e-06,
#   'nemity': 2.1126824153203216e-06,
#   'nemitx_err': 7.983777016756554e-08,
#   'nemity_err': 5.0109353714287776e-08,
#   'bmagx': 1.0773856131873742,
#   'bmagy': 1.0970829605791894,
#   'bmagx_err': 0.02255051827958238,
#   'bmagy_err': 0.02602100425835642,
#   'opt_q_x': -1.7550058858120954,
#   'opt_q_y': -4.991718153335276,
#   'quadvalsx': [-3.1742831630758284,
#    -2.701190737321251,
#    -2.2280983115666735,
#    -1.7550058858120954,
#    -1.2819134600575175,
#    -0.8088210343029401,
#    -0.3357286085483617,
#    0.06977918495556218,
#    0.8807947719634099],
#   'beamsizesx': [0.00023075116041582078,
#    0.00019525164680089802,
#    0.00016489808331243694,
#    0.0001453658624086529,
#    0.00014169230416882783,
#    0.0001655678206589073,
#    0.00020939434762112796,
#    0.0002537460532039404,
#    0.00035589421167969704],
#   'quadvalsy': [-6.393785782473394,
#    -5.926429906094022,
#    -5.459074029714649,
#    -4.991718153335276,
#    -4.524362276955903,
#    -4.057006400576529,
#    -3.589650524197157],
#   'beamsizesy': [0.0002169018262065947,
#    0.00015893585805315524,
#    0.00010909885168075562,
#    8.007789438124746e-05,
#    8.171638182830065e-05,
#    0.00012945821799803525,
#    0.00019892632553819567],
#   'nemit': 2.8387596937676393e-06,
#   'nemit_err': 8.979898615102739e-08},
#  20)

# %%
eval_emit_surrogate(
    get_bs_model=get_beamsizes_model,
    config=config_example,
    quad_init=np.linspace(-8, 0, 10),
    adapt_ranges=True,
    num_points=15,
    check_sym=True,
    infl_check=True,
    add_pnts=True,
    show_plots=True,
    add_noise=False,
    save_runs=False,
    calc_bmag=True,
)
# Out:
# ({'nemitx': 3.8128328672588393e-06,
#   'nemity': 2.0863054475703875e-06,
#   'nemitx_err': 7.249916227167343e-08,
#   'nemity_err': 3.6656997148831144e-08,
#   'bmagx': 1.0671897783031588,
#   'bmagy': 1.0437616381517354,
#   'bmagx_err': 0.020292094514884486,
#   'bmagy_err': 0.018339197377968224,
#   'opt_q_x': -1.9808046925504847,
#   'opt_q_y': -5.157364568203513,
#   'quadvalsx': [-2.8980963526854455,
#    -2.7146380206584535,
#    -2.5311796886314615,
#    -2.3477213566044695,
