# %%
import numpy as np
import matplotlib.pyplot as plt

# importing lcls surrogate model
# %cd ../
from lcls_functions import Lcls

# import pyemittance sample eval function
from pyemittance.emit_eval_example import eval_emit_surrogate
# Out:
# /Users/smiskov/Documents/SLAC/AD_Projects/emittance_opt_playground
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.compat.v2.summary API due to missing TensorBoard installation.
# WARNING:root:Limited tf.summary API due to missing TensorBoard installation.

# %% [markdown]
# # Initialize LCLS inj surrogate model

# %%
lcls = Lcls()
fn = lcls.beamsizes_list_fn
def fn_batch(x_list): return [fn(x) for x in x_list]

# define beamsize query function
def get_beamsizes_model(config, val):
    beamsizes_list = fn(config, [val])[0]
    xrms = beamsizes_list[0]
    yrms = beamsizes_list[1]
    xrms_err = xrms*0.03
    yrms_err = yrms*0.03
    
    return xrms, yrms, xrms_err, yrms_err
# Out:
# Add noise:  False

# %% [markdown]
# # Evaluate emittance for some injector configuration

# %% [markdown]
# ### this example function gets the emittance for a given set of injector paramters for: SOL1, CQ1, SQ1

# %%
config_example = [0.46, 0.001, -0.001]

# %%
eval_emit_surrogate?
# Out:
# Signature:
# eval_emit_surrogate(
#     get_bs_model,
#     inj_config=None,
#     quad_init=[-6, -4, -2, 0],
#     config_name='LCLS_OTR2',
#     config_dict=None,
#     adapt_ranges=True,
#     num_points=7,
#     check_sym=True,
#     infl_check=True,
#     add_pnts=True,
#     show_plots=False,
#     add_noise=False,
#     use_prev_meas=False,
#     quad_tol=0.05,
#     save_runs=False,
#     calc_bmag=False,
# )
# Docstring: <no docstring>
# File:      ~/Documents/SLAC/PyEmittance/pyemittance/emit_eval_example.py
# Type:      function

# %%
eval_emit_surrogate(
    get_bs_model=get_beamsizes_model,
    inj_config=config_example,
    config_name='sim',
    quad_init=[-6, -4, -2, 0],
    adapt_ranges=True,
    num_points=7,
    check_sym=False,
    infl_check=False,
    add_pnts=False,
    show_plots=True,
    add_noise=False,
    save_runs=False,
    calc_bmag=False,
)
# Out:
# ====================================================================================================
# * Calling get_beamsize function on [0.46, 0.001, -0.001, -6]
#
# * Beamsizes = (0.001417412008257889, 0.000710326111584011)
# ====================================================================================================
#
# ====================================================================================================
# * Calling get_beamsize function on [0.46, 0.001, -0.001, -4]
#
# * Beamsizes = (0.00074271990244034, 0.0002566111108257034)
# ====================================================================================================
#
# ====================================================================================================
# * Calling get_beamsize function on [0.46, 0.001, -0.001, -2]
#
# * Beamsizes = (0.00020437271504450665, 0.0012664850339982995)
# ====================================================================================================
#
# ====================================================================================================
# * Calling get_beamsize function on [0.46, 0.001, -0.001, 0]
#
# * Beamsizes = (0.00023170164165261644, 0.0022324871484856903)
# ====================================================================================================
#
# ====================================================================================================
# * Calling get_beamsize function on [0.46, 0.001, -0.001, -2.564874387087553]
#
# * Beamsizes = (0.0003288396526566934, 0.0009945587549105468)
# ====================================================================================================
#
# ====================================================================================================
# * Calling get_beamsize function on [0.46, 0.001, -0.001, -2.1373953225729605]
#
# * Beamsizes = (0.00023152994266063625, 0.0012011097184064627)
# ====================================================================================================
#
# ====================================================================================================
# * Calling get_beamsize function on [0.46, 0.001, -0.001, -1.7099162580583689]
#
# * Beamsizes = (0.00015915119891545684, 0.0014035105642877337)
# ====================================================================================================
#
# ====================================================================================================
# * Calling get_beamsize function on [0.46, 0.001, -0.001, -1.2824371935437766]
#
# * Beamsizes = (0.0001297515315109581, 0.0016036787235481301)
# ====================================================================================================
#
# ====================================================================================================
# * Calling get_beamsize function on [0.46, 0.001, -0.001, -0.8549581290291844]
#
# * Beamsizes = (0.00013883543211699962, 0.0018099045904691072)
# ====================================================================================================
#
# ====================================================================================================
# * Calling get_beamsize function on [0.46, 0.001, -0.001, -0.4274790645145924]
#
# * Beamsizes = (0.0001753351230211679, 0.00202319608528672)
# ====================================================================================================
#
# ====================================================================================================
# * Calling get_beamsize function on [0.46, 0.001, -0.001, 0.0]
#
# * Beamsizes = (0.00023170164165261644, 0.0022324871484856903)
# ====================================================================================================
#
# ====================================================================================================
# * Calling get_beamsize function on [0.46, 0.001, -0.001, -5.2860470078893425]
#
# * Beamsizes = (0.0011813982509437865, 0.0003855889038894848)
# ====================================================================================================
#
# ====================================================================================================
# * Calling get_beamsize function on [0.46, 0.001, -0.001, -5.0469433437614795]
#
# * Beamsizes = (0.0010972768117587161, 0.0002637591782414753)
# ====================================================================================================
#
# ====================================================================================================
# * Calling get_beamsize function on [0.46, 0.001, -0.001, -4.807839679633614]
#
# * Beamsizes = (0.001011850323926919, 0.00015295545772457772)
# ====================================================================================================
#
# ====================================================================================================
# * Calling get_beamsize function on [0.46, 0.001, -0.001, -4.568736015505749]
#
# * Beamsizes = (0.0009273716288107044, 0.00010279426906519844)
# ====================================================================================================
#
# ====================================================================================================
# * Calling get_beamsize function on [0.46, 0.001, -0.001, -4.329632351377883]
#
# * Beamsizes = (0.0008474859182409449, 0.00013182430983971948)
# ====================================================================================================
#
# ====================================================================================================
# * Calling get_beamsize function on [0.46, 0.001, -0.001, -4.090528687250019]
#
# * Beamsizes = (0.0007713003769318687, 0.00021597354259477196)
# ====================================================================================================
#
# ====================================================================================================
# * Calling get_beamsize function on [0.46, 0.001, -0.001, -3.8514250231221543]
#
# * Beamsizes = (0.0006958196761308401, 0.0003298095483250862)
# ====================================================================================================
#
# Savepaths not set. Please set them in 'configs/savepaths.json'
# Using examples directory:  /Users/smiskov/Documents/SLAC/PyEmittance/examples
# {'nemitx': 5.314370595952218e-06,
#  'nemity': 9.603876185987052e-06,
#  'nemitx_err': 1.2128568589437864e-07,
#  'nemity_err': 2.5258541178640433e-07,
#  'nemit': 7.144127463166886e-06,
#  'nemit_err': 2.4877184385608163e-07,
#  'bmagx': None,
#  'bmagy': None,
#  'bmagx_err': None,
#  'bmagy_err': None,
#  'bmag_emit': None,
#  'bmag_emit_err': None,
#  'opt_q_x': None,
#  'opt_q_y': None,
#  'total_points_measured': 18,
#  'quadvalsx': [-2.564874387087553,
#   -2.1373953225729605,
#   -1.7099162580583689,
#   -1.2824371935437766,
#   -0.8549581290291844,
#   -0.4274790645145924,
#   0.0],
#  'beamsizesx': [0.0003288396526566934,
#   0.00023152994266063625,
#   0.00015915119891545684,
#   0.0001297515315109581,
#   0.00013883543211699962,
#   0.0001753351230211679,
#   0.00023170164165261644],
#  'beamsizeserrx': [9.8651895797008e-06,
#   6.945898279819087e-06,
#   4.774535967463705e-06,
#   3.8925459453287425e-06,
#   4.165062963509988e-06,
#   5.260053690635037e-06,
#   6.951049249578493e-06],
#  'quadvalsy': [-5.2860470078893425,
#   -5.0469433437614795,
#   -4.807839679633614,
#   -4.568736015505749,
#   -4.329632351377883,
#   -4.090528687250019,
#   -3.8514250231221543],
#  'beamsizesy': [0.0003855889038894848,
#   0.0002637591782414753,
#   0.00015295545772457772,
#   0.00010279426906519844,
#   0.00013182430983971948,
#   0.00021597354259477196,
#   0.0003298095483250862],
#  'beamsizeserry': [1.1567667116684544e-05,
#   7.912775347244258e-06,
#   4.588663731737332e-06,
#   3.0838280719559532e-06,
#   3.954729295191584e-06,
#   6.479206277843158e-06,
#   9.894286449752585e-06]}

# %%
eval_emit_surrogate(
    get_bs_model=get_beamsizes_model,
    inj_config=config_example,
    config_name='sim',
    quad_init=[-6, -4, -2, 0],
    adapt_ranges=True,
    num_points=7,
    check_sym=False,
    infl_check=False,
    add_pnts=False,
    show_plots=True,
    add_noise=False,
    save_runs=False,
    calc_bmag=False,
)
# Out:
# ({'nemitx': 3.644416124040743e-06,
#   'nemity': 6.805056662338014e-06,
#   'nemitx_err': 8.527231778835872e-08,
#   'nemity_err': 1.8219970413335694e-07,
#   'bmagx': None,
#   'bmagy': None,
#   'bmagx_err': None,
#   'bmagy_err': None,
#   'opt_q_x': None,
#   'opt_q_y': None,
#   'quadvalsx': [-2.266346373115355,
#    -1.8886219775961293,
#    -1.5108975820769033,
#    -1.1331731865576775,
#    -0.7554487910384516,
#    -0.3777243955192257,
#    0.0],
#   'beamsizesx': [0.00025898677995428443,
#    0.00018452087533660233,
#    0.0001402947527822107,
#    0.00012881966540589929,
#    0.0001455820893170312,
#    0.00018101984460372478,
#    0.00023170167696662247],
#   'quadvalsy': [-5.309402179416212,
#    -5.056880464945729,
#    -4.804358750475245,
#    -4.55183703600476,
#    -4.299315321534277,
#    -4.046793607063794,
#    -3.79427189259331],
#   'beamsizesy': [0.00039761883090250194,
#    0.000268663396127522,
#    0.0001515791955171153,
#    0.00010248570470139384,
#    0.00014003021351527423,
#    0.00023512468033004552,
#    0.0003590795968193561],
#   'nemit': 4.980005845903752e-06,
#   'nemit_err': 1.7707585212028184e-07},
#  18)

# %%
config_example = [0.4762182125278053, -0.00027291415901526533, -0.0017033810831913413]

# %%
eval_emit_surrogate(
    get_bs_model=get_beamsizes_model,
    config=config_example,
    quad_init=[-6, -4, -2, 0],
    adapt_ranges=False,
    num_points=7,
    check_sym=False,
    infl_check=False,
    add_pnts=False,
    show_plots=True,
    add_noise=False,
    save_runs=False,
    calc_bmag=False,
)
# Out:
# ({'nemitx': 9.052085827236779e-07,
#   'nemity': 1.1114993848967974e-06,
#   'nemitx_err': 3.183139297329529e-08,
#   'nemity_err': 9.801564159317842e-08,
#   'bmagx': None,
#   'bmagy': None,
#   'bmagx_err': None,
#   'bmagy_err': None,
#   'opt_q_x': None,
#   'opt_q_y': None,
#   'quadvalsx': [-6, -4, -2, 0],
#   'beamsizesx': [0.00030772993341088295,
#    0.0001644843869144097,
#    7.864710642024875e-05,
#    9.804828005144373e-05],
#   'quadvalsy': [-6, -4, -2, 0],
#   'beamsizesy': [0.00017794866289477795,
#    6.531506369356066e-05,
#    0.00024861126439645886,
#    0.0004766665806528181],
#   'nemit': 1.0030646952717804e-06,
#   'nemit_err': 9.522695050973561e-08},
#  4)

# %%
config_example = [0.40237315794103, 0.109867181010308325, 0.009635943489050674]

# %%
eval_emit_surrogate(
    get_bs_model=get_beamsizes_model,
    config=config_example,
    quad_init=[-4,-2, 0, 1],
    adapt_ranges=True,
    num_points=5,
    check_sym=True,
    infl_check=False,
    add_pnts=False,
    show_plots=True,
    add_noise=False,
    save_runs=False,
    calc_bmag=False,
)
# Out:
# ({'nemitx': 9.82084002891222e-05,
#   'nemity': 6.572819964563979e-05,
#   'nemitx_err': 3.901098902439395e-06,
#   'nemity_err': 2.3689020188218115e-06,
#   'bmagx': None,
#   'bmagy': None,
#   'bmagx_err': None,
#   'bmagy_err': None,
#   'opt_q_x': None,
#   'opt_q_y': None,
#   'quadvalsx': [-1.9999999999999998,
#    -1.1960495423777127,
#    -0.3920990847554256,
#    0.4118513728668618,
#    1.215801830489149],
#   'beamsizesx': [0.0011920641409233212,
#    0.0009120642789639533,
#    0.000847330957185477,
#    0.0009442361770197749,
#    0.0012076974380761385],
#   'quadvalsy': [-5.2158018304891485,
#    -4.878356280261218,
#    -4.5409107300332865,
#    -4.203465179805355,
#    -3.866019629577424],
#   'beamsizesy': [0.0005493679200299084,
#    0.0004615760990418494,
#    0.0004386945511214435,
#    0.0005453792400658131,
#    0.0007666285964660347],
#   'nemit': 8.034339637507449e-05,
#   'nemit_err': 4.309308975259467e-06},
#  14)

# %%
eval_emit_surrogate(
    get_bs_model=get_beamsizes_model,
    inj_config=config_example,
    quad_init=[-4,-2, 0, 1],
    config_name='sim',
    adapt_ranges=True,
    num_points=5,
    check_sym=True,
    infl_check=True,
    add_pnts=True,
    show_plots=True,
    add_noise=True,
    save_runs=True,
    calc_bmag=True,
)
# Out:
# Savepaths not set. Please set them in 'configs/savepaths.json'
# Using examples directory:  /Users/smiskov/Documents/SLAC/PyEmittance/examples
# {'nemitx': 5.295706800972351e-06,
#  'nemity': 1.0664957288929251e-05,
#  'nemitx_err': 1.4870529249541632e-07,
#  'nemity_err': 3.514439359853308e-07,
#  'nemit': 7.515217019292409e-06,
#  'nemit_err': 3.253677653106832e-07,
#  'bmagx': 1.0318425416581143,
#  'bmagy': 1.8375734886284363,
#  'bmagx_err': 0.0289744981610953,
#  'bmagy_err': 0.06055383458465136,
#  'bmag_emit': 1.0348337856588146e-05,
#  'bmag_emit_err': 6.336049992762418e-07,
#  'opt_q_x': -1.456547634275006,
#  'opt_q_y': -4.861994911959471,
#  'total_points_measured': 16,
#  'quadvalsx': [-3.1996500729355324,
#   -2.663310861039986,
#   -2.1269716491444393,
#   -1.456547634275006,
#   -0.7861236194055724,
#   -0.11569960453613885,
#   0.5547244103332944],
#  'beamsizesx': [0.0005041014641621125,
#   0.00035955070876100126,
#   0.00023719565058274086,
#   0.0001382835618047821,
#   0.00014937627408942192,
#   0.0002188441126924833,
#   0.0003076960741989337],
#  'beamsizeserrx': [1.537809260751959e-05,
#   1.1500114757034394e-05,
#   7.237538068664259e-06,
#   4.370933731169906e-06,
#   4.917860714596596e-06,
#   6.516745224694362e-06,
#   9.452708125056912e-06],
#  'quadvalsy': [-5.2158018304891485,
#   -4.861994911959471,
#   -4.508187993429794,
#   -4.154381074900117,
#   -3.8005741563704407],
#  'beamsizesy': [0.00035699543913499744,
#   0.00018609160781021437,
#   0.00010955487675237078,
#   0.0001927763778881659,
#   0.0003626944033303363],
#  'beamsizeserry': [1.1167724138735713e-05,
#   5.847343567034706e-06,
#   3.835265200326393e-06,
#   5.8556692676733515e-06,
#   1.1432120745719516e-05]}
