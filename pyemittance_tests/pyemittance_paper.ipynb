# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %cd ../../

# importing lcls surrogate model
from lcls_functions import Lcls

# import pyemittance sample eval function
from pyemittance.emit_eval_example import eval_emit_surrogate

# %%
lcls = Lcls()
fn = lcls.beamsizes_list_fn
def fn_batch(x_list): return [fn(x) for x in x_list]

# define beamsize query function
def get_beamsizes_model(config, val):
    beamsizes_list = fn(config, [val])[0]
    xrms = beamsizes_list[0]
    yrms = beamsizes_list[1]
    xrms_err = xrms*0.03
    yrms_err = yrms*0.03
    
    return xrms, yrms, xrms_err, yrms_err
# Out:
# Add noise:  False

# %%
config_example = [0.500237315794103, -0.01867181010308325, -0.00135943489050674]

# %%
eval_emit_surrogate(
    get_bs_model=get_beamsizes_model,
    config=config_example,
    quad_init=[-6, -4, -2, 0],
    adapt_ranges=True,
    num_points=7,
    check_sym=True,
    infl_check=True,
    add_pnts=False,
    show_plots=True,
    add_noise=False,
    save_runs=False,
    calc_bmag=False,
)
# Out:
# ====================================================================================================
# * Calling get_beamsize function on [0.500237315794103, -0.01867181010308325, -0.00135943489050674, -6]
#
# ====================================================================================================
# * Calling get_beamsize function on [0.500237315794103, -0.01867181010308325, -0.00135943489050674, -4]
#
# ====================================================================================================
# * Calling get_beamsize function on [0.500237315794103, -0.01867181010308325, -0.00135943489050674, -2]
#
# ====================================================================================================
# * Calling get_beamsize function on [0.500237315794103, -0.01867181010308325, -0.00135943489050674, 0]
#
# ====================================================================================================
# * Calling get_beamsize function on [0.500237315794103, -0.01867181010308325, -0.00135943489050674, -2.926025160635587]
#
# ====================================================================================================
# * Calling get_beamsize function on [0.500237315794103, -0.01867181010308325, -0.00135943489050674, -2.2357206621147983]
#
# ====================================================================================================
# * Calling get_beamsize function on [0.500237315794103, -0.01867181010308325, -0.00135943489050674, -1.5454161635940085]
#
# ====================================================================================================
# * Calling get_beamsize function on [0.500237315794103, -0.01867181010308325, -0.00135943489050674, -0.8551116650732196]
#
# ====================================================================================================
# * Calling get_beamsize function on [0.500237315794103, -0.01867181010308325, -0.00135943489050674, -0.16480716655243002]
#
# ====================================================================================================
# * Calling get_beamsize function on [0.500237315794103, -0.01867181010308325, -0.00135943489050674, 0.5254973319683593]
#
# ====================================================================================================
# * Calling get_beamsize function on [0.500237315794103, -0.01867181010308325, -0.00135943489050674, 1.215801830489149]
#
# ====================================================================================================
# * Calling get_beamsize function on [0.500237315794103, -0.01867181010308325, -0.00135943489050674, -5.165299206079457]
#
# ====================================================================================================
# * Calling get_beamsize function on [0.500237315794103, -0.01867181010308325, -0.00135943489050674, -4.920411343407965]
#
# ====================================================================================================
# * Calling get_beamsize function on [0.500237315794103, -0.01867181010308325, -0.00135943489050674, -4.675523480736473]
#
# ====================================================================================================
# * Calling get_beamsize function on [0.500237315794103, -0.01867181010308325, -0.00135943489050674, -4.43063561806498]
#
# ====================================================================================================
# * Calling get_beamsize function on [0.500237315794103, -0.01867181010308325, -0.00135943489050674, -4.185747755393487]
#
# ====================================================================================================
# * Calling get_beamsize function on [0.500237315794103, -0.01867181010308325, -0.00135943489050674, -3.9408598927219938]
#
# ====================================================================================================
# * Calling get_beamsize function on [0.500237315794103, -0.01867181010308325, -0.00135943489050674, -3.695972030050502]
#
# ====================================================================================================
# * Calling get_beamsize function on [0.500237315794103, -0.01867181010308325, -0.00135943489050674, 1.8074914006498255]
#
# ====================================================================================================
# * Calling get_beamsize function on [0.500237315794103, -0.01867181010308325, -0.00135943489050674, 2.5964108275307276]
#
# ====================================================================================================
# * Calling get_beamsize function on [0.500237315794103, -0.01867181010308325, -0.00135943489050674, 3.3853302544116293]
#
# ====================================================================================================
# * Calling get_beamsize function on [0.500237315794103, -0.01867181010308325, -0.00135943489050674, 4.174249681292531]
#
# ====================================================================================================
# * Calling get_beamsize function on [0.500237315794103, -0.01867181010308325, -0.00135943489050674, -5.585106970659158]
#
# ====================================================================================================
# * Calling get_beamsize function on [0.500237315794103, -0.01867181010308325, -0.00135943489050674, -5.375203088369307]
# ({'nemitx': 6.258567442952866e-05,
#   'nemity': 6.393541788795808e-06,
#   'nemitx_err': 2.654260090076714e-06,
#   'nemity_err': 1.610448588625509e-07,
#   'bmagx': None,
#   'bmagy': None,
#   'bmagx_err': None,
#   'bmagy_err': None,
#   'opt_q_x': None,
#   'opt_q_y': None,
#   'quadvalsx': [-0.8551116650732196,
#    -0.16480716655243002,
#    0.5254973319683593,
#    1.215801830489149,
#    1.8074914006498255,
#    2.5964108275307276,
#    3.3853302544116293,
#    4.174249681292531],
#   'beamsizesx': [0.0009222954977303743,
#    0.00081711943494156,
#    0.0008054635254666209,
#    0.0008815878536552191,
#    0.0009866597829386592,
#    0.001161445863544941,
#    0.0013489506673067808,
#    0.0015169908292591572],
#   'quadvalsy': [-5.585106970659158,
#    -5.375203088369307,
#    -5.165299206079457,
#    -4.920411343407965,
#    -4.675523480736473,
#    -4.43063561806498,
#    -4.185747755393487,
#    -3.9408598927219938,
#    -3.695972030050502],
#   'beamsizesy': [0.0003977193555328995,
#    0.0003041676536668092,
#    0.00021904215100221336,
#    0.00013730644423048943,
#    9.28640365600586e-05,
#    0.00010212892811978236,
#    0.00015882981824688613,
#    0.00023795850574970245,
#    0.0003237640194129199],
#   'nemit': 2.000360279662543e-05,
#   'nemit_err': 9.867028803602305e-07},
#  24)
